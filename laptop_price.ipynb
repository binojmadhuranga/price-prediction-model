# %%
# !pip install numpy
# !pip install pandas
# Out:
# Requirement already satisfied: numpy in c:\users\binoj\onedrive\desktop\ai & ml\laptop_price\env\lib\site-packages (2.3.5)
# Requirement already satisfied: pandas in c:\users\binoj\onedrive\desktop\ai & ml\laptop_price\env\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\binoj\onedrive\desktop\ai & ml\laptop_price\env\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\binoj\onedrive\desktop\ai & ml\laptop_price\env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\binoj\onedrive\desktop\ai & ml\laptop_price\env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\binoj\onedrive\desktop\ai & ml\laptop_price\env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\binoj\onedrive\desktop\ai & ml\laptop_price\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #ADD RESOURCE DATA SET

# %%
url = r"C:\Users\binoj\OneDrive\Desktop\AI & ML\Laptop_Price\laptop_price.csv"
data = pd.read_csv(url, encoding='latin1')
print(data.head())
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60

# %%
data.info()
print(data.describe())
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000
# (1303, 12)

# %%
data['Ram'] = data['Ram'].str.replace('GB', '', regex=False).astype('int32')
data['Weight'] = data['Weight'].str.replace('kg', '', regex=False).astype('float32')

# %%
data.info()
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   int32
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price_euros       1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), int64(1), object(7)
# memory usage: 112.1+ KB
#          laptop_ID       Inches          Ram       Weight  Price_euros
# count  1303.000000  1303.000000  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191     8.382195     2.038734  1123.686992
# std     381.172104     1.426304     5.084665     0.665475   699.009043
# min       1.000000    10.100000     2.000000     0.690000   174.000000
# 25%     331.500000    14.000000     4.000000     1.500000   599.000000
# 50%     659.000000    15.600000     8.000000     2.040000   977.000000
# 75%     990.500000    15.600000     8.000000     2.300000  1487.880000
# max    1320.000000    18.400000    64.000000     4.700000  6099.000000

# %%
data.corr(numeric_only=True)['Price_euros']
# Out:
# laptop_ID      0.067830
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price_euros    1.000000
# Name: Price_euros, dtype: float64

# %% [markdown]
# ##Company Column

# %%
data['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# Google         3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
def add_company(inpt):
    if inpt == 'Samsung' or inpt == 'Razer' or inpt == 'Mediacom' or inpt == 'Microsoft'or inpt == 'Xiaomi'or inpt == 'Vero'or inpt == 'Chuwi'or inpt == 'Google'or inpt == 'Fujitsu'or inpt == 'LG'or inpt == 'Huawei':
        return 'Other'
    else:
        return inpt

# %%
data['Company'] = data['Company'].apply(add_company)
data['Company'].value_counts()
# Out:
# Company
# Dell       297
# Lenovo     297
# HP         274
# Asus       158
# Acer       103
# MSI         54
# Other       51
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
len(data['Product'].value_counts())
# Out:
# 618

# %%
data['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
data['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# 1440x900                                           4
# IPS Panel Touchscreen 1920x1200                    4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# IPS Panel Touchscreen 1366x768                     3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# 2560x1440                                          3
# Touchscreen 2400x1600                              3
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1920x1200                        1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
data['Touchscreen'] = data['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
data['Ips'] = data['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
data.head(2)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
#
#                      ScreenResolution                   Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz    8
# 1                            1440x900  Intel Core i5 1.8GHz    8
#
#                             Gpu  OpSys  Weight  Price_euros  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69            0    1
# 1        Intel HD Graphics 6000  macOS    1.34       898.94            0    0

# %%
data['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core i5 7200U 2.70GHz        1
# Intel Core M M7-6Y75 1.2GHz        1
# Intel Core M 6Y54 1.1GHz           1
# AMD E-Series 9000 2.2GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# Name: count, Length: 118, dtype: int64

# %%
data['cpu_name'] = data['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
data['cpu_name'].value_counts()
# Out:
# cpu_name
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# Intel Celeron Quad            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# AMD A8-Series 7410            4
# Intel Atom x5-Z8550           4
# AMD A9-Series 9410            3
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD E-Series E2-9000e         2
# AMD A10-Series A10-9620P      2
# AMD A6-Series A6-9220         2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1505M           2
# Intel Xeon E3-1535M           2
# Intel Atom X5-Z8350           2
# Intel Atom x5-Z8300           1
# AMD E-Series 6110             1
# AMD E-Series 9000e            1
# AMD E-Series E2-6110          1
# AMD FX 9830P                  1
# AMD Ryzen 1600                1
# Intel Atom Z8350              1
# AMD A6-Series 7310            1
# AMD E-Series E2-9000          1
# AMD A12-Series 9700P          1
# AMD FX 8800P                  1
# AMD A4-Series 7210            1
# Samsung Cortex A72&A53        1
# AMD E-Series 9000             1
# Name: count, dtype: int64

# %%
def set_processor(name):
    if name == 'Intel Core i7' or name == 'Intel Core i5' or name == 'Intel Core i3':
        return name
    else:
        if name.split()[0] == 'AMD':
            return 'AMD'
        else:
            return 'Other'

# %%
data['cpu_name'] = data['cpu_name'].apply(set_processor)

# %%
data['cpu_name'].value_counts()
# Out:
# cpu_name
# Intel Core i7    527
# Intel Core i5    423
# Other            155
# Intel Core i3    136
# AMD               62
# Name: count, dtype: int64

# %%
data['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
data['gpu_name'] = data['Gpu'].apply(lambda x:" ".join(x.split()[0:1]))

# %%
data['gpu_name'].value_counts()
# Out:
# gpu_name
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (1303, 16)

# %%
data = data[data['gpu_name'] != 'ARM']

# %%
data.shape
# Out:
# (1302, 16)

# %%
data.head(2)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
#
#                      ScreenResolution                   Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz    8
# 1                            1440x900  Intel Core i5 1.8GHz    8
#
#                             Gpu  OpSys  Weight  Price_euros  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69            0    1
# 1        Intel HD Graphics 6000  macOS    1.34       898.94            0    0
#
#         cpu_name gpu_name
# 0  Intel Core i5    Intel
# 1  Intel Core i5    Intel

# %%
data['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def set_os(inpt):
    if inpt == 'Windows 10' or inpt == 'Windows 7' or inpt == 'Windows 10 S':
        return 'Windows'
    elif inpt == 'macOS' or inpt == 'Mac OS X':
        return 'Mac'
    elif inpt == 'Linux':
        return inpt
    else:
        return 'Other'

# %%
data['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %% [markdown]
# #Drop unnecessary columns

# %%
data = data.drop(columns=['laptop_ID', 'Inches', 'Product', 'ScreenResolution', 'Cpu', 'Gpu'])

# %%
data.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight  Price_euros  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37      1339.69            0    1
# 1   Apple  Ultrabook    8  macOS    1.34       898.94            0    0
# 2      HP   Notebook    8  No OS    1.86       575.00            0    0
# 3   Apple  Ultrabook   16  macOS    1.83      2537.45            0    1
# 4   Apple  Ultrabook    8  macOS    1.37      1803.60            0    1
#
#         cpu_name gpu_name
# 0  Intel Core i5    Intel
# 1  Intel Core i5    Intel
# 2  Intel Core i5    Intel
# 3  Intel Core i7      AMD
# 4  Intel Core i5    Intel

# %% [markdown]
# #One-Hot Encoding

# %%
data = pd.get_dummies(data)

# %%
data.head(2)
# Out:
#    Ram  Weight  Price_euros  Touchscreen  Ips  Company_Acer  Company_Apple  \
# 0    8    1.37      1339.69            0    1         False           True
# 1    8    1.34       898.94            0    0         False           True
#
#    Company_Asus  Company_Dell  Company_HP  ...  OpSys_Windows 7  OpSys_macOS  \
# 0         False         False       False  ...            False         True
# 1         False         False       False  ...            False         True
#
#    cpu_name_AMD  cpu_name_Intel Core i3  cpu_name_Intel Core i5  \
# 0         False                   False                    True
# 1         False                   False                    True
#
#    cpu_name_Intel Core i7  cpu_name_Other  gpu_name_AMD  gpu_name_Intel  \
# 0                   False           False         False            True
# 1                   False           False         False            True
#
#    gpu_name_Nvidia
# 0            False
# 1            False
#
# [2 rows x 37 columns]

# %%
data.shape
# Out:
# (1302, 37)

# %%
X = data.drop('Price_euros', axis=1)
y = data['Price_euros']

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\binoj\onedrive\desktop\ai & ml\laptop_price\env\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\binoj\onedrive\desktop\ai & ml\laptop_price\env\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\binoj\onedrive\desktop\ai & ml\laptop_price\env\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\binoj\onedrive\desktop\ai & ml\laptop_price\env\lib\site-packages (from scikit-learn) (3.6.0)
# Using cached scikit_learn-1.7.2-cp311-cp311-win_amd64.whl (8.9 MB)
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.7.2
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\binoj\onedrive\desktop\ai & ml\laptop_price\env\lib\site-packages (from scikit-learn) (2.3.5)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp311-cp311-win_amd64.whl (8.9 MB)
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.9 MB 1.9 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/8.9 MB 1.6 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/8.9 MB 1.6 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.9 MB 1.6 MB/s eta 0:00:05
#    --------- ------------------------------ 2.1/8.9 MB 1.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.4/8.9 MB 1.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.6/8.9 MB 1.7 MB/s eta 0:00:04
#    ------------ --------------------------- 2.9/8.9 MB 1.7 MB/s eta 0:00:04
#    -------------- ------------------------- 3.1/8.9 MB 1.6 MB/s eta 0:00:04
#    --------------- ------------------------ 3.4/8.9 MB 1.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.7/8.9 MB 1.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.9/8.9 MB 1.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.9/8.9 MB 1.5 MB/s eta 0:00:04
#    ------------------ --------------------- 4.2/8.9 MB 1.4 MB/s eta 0:00:04
#    --------------------- ------------------ 4.7/8.9 MB 1.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.0/8.9 MB 1.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.2/8.9 MB 1.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.2/8.9 MB 1.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.2/8.9 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.8/8.9 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 6.0/8.9 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 6.3/8.9 MB 1.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.6/8.9 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 6.8/8.9 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 7.1/8.9 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 7.3/8.9 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 7.6/8.9 MB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.9/8.9 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 8.1/8.9 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 8.7/8.9 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 1.3 MB/s  0:00:06
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading scipy-1.16.3-cp311-cp311-win_amd64.whl (38.7 MB)
#    ---------------------------------------- 0.0/38.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.7 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.7 MB 1.5 MB/s eta 0:00:25
#     --------------------------------------- 0.8/38.7 MB 1.3 MB/s eta 0:00:29
#    - -------------------------------------- 1.0/38.7 MB 1.3 MB/s eta 0:00:29
#    - -------------------------------------- 1.3/38.7 MB 1.2 MB/s eta 0:00:32
#    - -------------------------------------- 1.8/38.7 MB 1.3 MB/s eta 0:00:28
#    -- ------------------------------------- 2.1/38.7 MB 1.4 MB/s eta 0:00:27
#    -- ------------------------------------- 2.4/38.7 MB 1.4 MB/s eta 0:00:26
#    -- ------------------------------------- 2.6/38.7 MB 1.4 MB/s eta 0:00:26
#    -- ------------------------------------- 2.9/38.7 MB 1.4 MB/s eta 0:00:27
#    --- ------------------------------------ 3.4/38.7 MB 1.4 MB/s eta 0:00:25
#    --- ------------------------------------ 3.7/38.7 MB 1.4 MB/s eta 0:00:25
#    ---- ----------------------------------- 4.2/38.7 MB 1.5 MB/s eta 0:00:23
#    ---- ----------------------------------- 4.7/38.7 MB 1.6 MB/s eta 0:00:22
#    ----- ---------------------------------- 5.2/38.7 MB 1.6 MB/s eta 0:00:21
#    ----- ---------------------------------- 5.8/38.7 MB 1.7 MB/s eta 0:00:20
#    ------ --------------------------------- 6.0/38.7 MB 1.7 MB/s eta 0:00:20
#    ------ --------------------------------- 6.3/38.7 MB 1.7 MB/s eta 0:00:20
#    ------ --------------------------------- 6.3/38.7 MB 1.7 MB/s eta 0:00:20
#    ------- -------------------------------- 6.8/38.7 MB 1.6 MB/s eta 0:00:21
#    ------- -------------------------------- 7.1/38.7 MB 1.6 MB/s eta 0:00:20
#    ------- -------------------------------- 7.6/38.7 MB 1.6 MB/s eta 0:00:20
#    -------- ------------------------------- 8.1/38.7 MB 1.7 MB/s eta 0:00:19
#    -------- ------------------------------- 8.4/38.7 MB 1.7 MB/s eta 0:00:19
#    --------- ------------------------------ 8.9/38.7 MB 1.7 MB/s eta 0:00:18
#    --------- ------------------------------ 9.4/38.7 MB 1.7 MB/s eta 0:00:18
#    ---------- ----------------------------- 9.7/38.7 MB 1.7 MB/s eta 0:00:17
#    ---------- ----------------------------- 10.2/38.7 MB 1.7 MB/s eta 0:00:17
#    ---------- ----------------------------- 10.5/38.7 MB 1.7 MB/s eta 0:00:17
#    ---------- ----------------------------- 10.5/38.7 MB 1.7 MB/s eta 0:00:17
#    ----------- ---------------------------- 10.7/38.7 MB 1.7 MB/s eta 0:00:17
#    ----------- ---------------------------- 11.0/38.7 MB 1.6 MB/s eta 0:00:17
#    ----------- ---------------------------- 11.5/38.7 MB 1.6 MB/s eta 0:00:17
#    ------------ --------------------------- 11.8/38.7 MB 1.7 MB/s eta 0:00:17
#    ------------ --------------------------- 12.1/38.7 MB 1.7 MB/s eta 0:00:17
#    ------------ --------------------------- 12.6/38.7 MB 1.7 MB/s eta 0:00:16
#    ------------- -------------------------- 12.8/38.7 MB 1.7 MB/s eta 0:00:16
#    ------------- -------------------------- 12.8/38.7 MB 1.7 MB/s eta 0:00:16
#    ------------- -------------------------- 13.1/38.7 MB 1.6 MB/s eta 0:00:17
#    ------------- -------------------------- 13.4/38.7 MB 1.6 MB/s eta 0:00:17
#    -------------- ------------------------- 13.6/38.7 MB 1.6 MB/s eta 0:00:16
#    -------------- ------------------------- 13.9/38.7 MB 1.6 MB/s eta 0:00:16
#    -------------- ------------------------- 13.9/38.7 MB 1.6 MB/s eta 0:00:16
#    -------------- ------------------------- 13.9/38.7 MB 1.6 MB/s eta 0:00:16
#    -------------- ------------------------- 13.9/38.7 MB 1.6 MB/s eta 0:00:16
#    -------------- ------------------------- 14.2/38.7 MB 1.5 MB/s eta 0:00:17
#    --------------- ------------------------ 14.7/38.7 MB 1.5 MB/s eta 0:00:17
#    --------------- ------------------------ 14.9/38.7 MB 1.5 MB/s eta 0:00:17
#    --------------- ------------------------ 15.2/38.7 MB 1.5 MB/s eta 0:00:16
#    --------------- ------------------------ 15.5/38.7 MB 1.5 MB/s eta 0:00:16
#    ---------------- ----------------------- 16.0/38.7 MB 1.5 MB/s eta 0:00:16
#    ---------------- ----------------------- 16.3/38.7 MB 1.5 MB/s eta 0:00:16
#    ----------------- ---------------------- 16.8/38.7 MB 1.5 MB/s eta 0:00:15
#    ----------------- ---------------------- 17.0/38.7 MB 1.5 MB/s eta 0:00:15
#    ------------------ --------------------- 17.6/38.7 MB 1.5 MB/s eta 0:00:14
#    ------------------ --------------------- 17.8/38.7 MB 1.5 MB/s eta 0:00:14
#    ------------------ --------------------- 18.1/38.7 MB 1.5 MB/s eta 0:00:14
#    ------------------ --------------------- 18.4/38.7 MB 1.5 MB/s eta 0:00:14
#    ------------------- -------------------- 18.6/38.7 MB 1.5 MB/s eta 0:00:14
#    ------------------- -------------------- 19.1/38.7 MB 1.5 MB/s eta 0:00:13
#    -------------------- ------------------- 19.7/38.7 MB 1.5 MB/s eta 0:00:13
#    -------------------- ------------------- 19.9/38.7 MB 1.5 MB/s eta 0:00:13
#    --------------------- ------------------ 20.4/38.7 MB 1.5 MB/s eta 0:00:12
#    --------------------- ------------------ 20.7/38.7 MB 1.5 MB/s eta 0:00:12
#    --------------------- ------------------ 21.2/38.7 MB 1.6 MB/s eta 0:00:12
#    ---------------------- ----------------- 21.5/38.7 MB 1.6 MB/s eta 0:00:12
#    ---------------------- ----------------- 22.0/38.7 MB 1.6 MB/s eta 0:00:11
#    ----------------------- ---------------- 22.3/38.7 MB 1.6 MB/s eta 0:00:11
#    ----------------------- ---------------- 22.8/38.7 MB 1.6 MB/s eta 0:00:11
#    ----------------------- ---------------- 23.1/38.7 MB 1.6 MB/s eta 0:00:10
#    ------------------------ --------------- 23.3/38.7 MB 1.6 MB/s eta 0:00:10
#    ------------------------ --------------- 23.9/38.7 MB 1.6 MB/s eta 0:00:10
#    ------------------------- -------------- 24.4/38.7 MB 1.6 MB/s eta 0:00:10
#    ------------------------- -------------- 24.6/38.7 MB 1.6 MB/s eta 0:00:09
#    ------------------------- -------------- 24.9/38.7 MB 1.6 MB/s eta 0:00:09
#    -------------------------- ------------- 25.4/38.7 MB 1.6 MB/s eta 0:00:09
#    -------------------------- ------------- 26.0/38.7 MB 1.6 MB/s eta 0:00:08
#    --------------------------- ------------ 26.2/38.7 MB 1.6 MB/s eta 0:00:08
#    --------------------------- ------------ 26.7/38.7 MB 1.6 MB/s eta 0:00:08
#    ---------------------------- ----------- 27.3/38.7 MB 1.6 MB/s eta 0:00:08
#    ---------------------------- ----------- 27.5/38.7 MB 1.6 MB/s eta 0:00:07
#    ---------------------------- ----------- 28.0/38.7 MB 1.6 MB/s eta 0:00:07
#    ----------------------------- ---------- 28.6/38.7 MB 1.6 MB/s eta 0:00:07
#    ------------------------------ --------- 29.1/38.7 MB 1.7 MB/s eta 0:00:06
#    ------------------------------ --------- 29.6/38.7 MB 1.7 MB/s eta 0:00:06
#    ------------------------------- -------- 30.1/38.7 MB 1.7 MB/s eta 0:00:06
#    ------------------------------- -------- 30.7/38.7 MB 1.7 MB/s eta 0:00:05
#    -------------------------------- ------- 31.2/38.7 MB 1.7 MB/s eta 0:00:05
#    -------------------------------- ------- 31.7/38.7 MB 1.7 MB/s eta 0:00:05
#    --------------------------------- ------ 32.2/38.7 MB 1.7 MB/s eta 0:00:04
#    --------------------------------- ------ 32.8/38.7 MB 1.7 MB/s eta 0:00:04
#    ---------------------------------- ----- 33.3/38.7 MB 1.7 MB/s eta 0:00:04
#    ---------------------------------- ----- 33.3/38.7 MB 1.7 MB/s eta 0:00:04
#    ---------------------------------- ----- 33.3/38.7 MB 1.7 MB/s eta 0:00:04
#    ---------------------------------- ----- 33.8/38.7 MB 1.7 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.1/38.7 MB 1.7 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.3/38.7 MB 1.7 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.6/38.7 MB 1.7 MB/s eta 0:00:03
#    ------------------------------------ --- 35.1/38.7 MB 1.7 MB/s eta 0:00:03
#    ------------------------------------ --- 35.1/38.7 MB 1.7 MB/s eta 0:00:03
#    ------------------------------------ --- 35.1/38.7 MB 1.7 MB/s eta 0:00:03
#    ------------------------------------ --- 35.7/38.7 MB 1.7 MB/s eta 0:00:02
#    ------------------------------------- -- 36.2/38.7 MB 1.7 MB/s eta 0:00:02
#    ------------------------------------- -- 36.4/38.7 MB 1.7 MB/s eta 0:00:02
#    ------------------------------------- -- 36.7/38.7 MB 1.7 MB/s eta 0:00:02
#    ------------------------------------- -- 36.7/38.7 MB 1.7 MB/s eta 0:00:02
#    ------------------------------------- -- 36.7/38.7 MB 1.7 MB/s eta 0:00:02
#    -------------------------------------- - 37.0/38.7 MB 1.6 MB/s eta 0:00:02
#    -------------------------------------- - 37.2/38.7 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/38.7 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 37.7/38.7 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.7 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.7 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.7 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 38.7/38.7 MB 1.6 MB/s  0:00:24
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ---------------------------------------- 4/4 [scikit-learn]
#
# Successfully installed joblib-1.5.2 scikit-learn-1.7.2 scipy-1.16.3 threadpoolctl-3.6.0

# %% [markdown]
# #Divide dataset into training and testing set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
X_train.shape, X_test.shape
# Out:
# ((976, 36), (326, 36))

# %%
def model_acc(model):
    model.fit(X_train, y_train)
    acc = model.score(X_test, y_test)
    print(str(model)+ ' --> ' +str(acc))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
model_acc(lr)

from sklearn.linear_model import Lasso
lasso = Lasso()
model_acc(lasso)

from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
model_acc(dt)

from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
model_acc(rf)
# Out:
# LinearRegression() --> 0.709185812769838
# Lasso() --> 0.7050042583015721
# DecisionTreeRegressor() --> 0.7003611665254652
# RandomForestRegressor() --> 0.807927549071539
